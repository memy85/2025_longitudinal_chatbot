# %%
import pandas as pd
from utils import *
DATA_PATH = PROJECT_PATH.joinpath("data/processed")

# %%
# df = pd.read_excel(PROJECT_PATH.joinpath("data/raw/annotation_notes.xlsx"))
df = pd.read_pickle(PROJECT_PATH.joinpath("data/raw/pitts_and_mimic.pkl"))

# %%
df
# Out:
#      data_source         note_id  \
# 0          pitts      report7660
# 1          pitts      report4725
# 2          pitts      report5005
# 3          pitts      report2854
# 4          pitts      report6420
# ...          ...             ...
# 9995       mimic  13390532-DS-20
# 9996       mimic  15286481-DS-16
# 9997       mimic  14584705-DS-19
# 9998       mimic   18813076-DS-8
# 9999       mimic   11981568-DS-2
#
#                                                   texts  \
# 0     [ Report de-identified ( Safe-harbor compliant...
# 1     [ Report de-identified ( Safe-harbor compliant...
# 2     [ Report de-identified ( Safe-harbor compliant...
# 3     [ Report de-identified ( Safe-harbor compliant...
# 4     [ Report de-identified ( Safe-harbor compliant...
# ...                                                 ...
# 9995   \nName:  ___.              Unit No:   ___\n \...
# 9996   \nName:  ___               Unit No:   ___\n \...
# ...
